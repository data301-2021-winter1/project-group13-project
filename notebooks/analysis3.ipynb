# %% [markdown]
# # Tanner Bjorgan

# %% [markdown]
# ## Research question/interests
# I would like to see what languages are used the most/in high demand in this industry or what languages are needed to get into more niche careers.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Milestone 2**

# %%
df2021 = pd.read_csv('../data/raw/survey_results_public_2021.csv')

# %%
df2021.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
df2021.tail()
# Out:
#        ResponseId                      MainBranch  \
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                         Country    US_State UK_Country  \
# 83434  United States of America       Texas        NaN
# 83435                     Benin         NaN        NaN
# 83436  United States of America  New Jersey        NaN
# 83437                    Canada         NaN        NaN
# ...

# %% [markdown]
# ## **Milestone 3**
# ### **Task1** : EDA

# %%
import seaborn as sns
import matplotlib.pylab as plt
import project_functions3 as p3
from collections import Counter

# %% [markdown]
# Displaying the unprossed data from the dataset to better understand the data and to know what needs to be cleaned.

# %%
dfU2021 = p3.loadU('../data/raw/survey_results_public_2021.csv')
dfU2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %% [markdown]
# Found 83439 entries in 9 columns and shows null values in each column

# %%
print(f"List of the columns found: {dfU2021.columns}")
# Out:
# List of the columns found: Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
# ...

# %%
print(f"Number of unique values per column: {dfU2021.nunique(axis=0)}")
# Out:
# Number of unique values per column: ResponseId                      83439
# MainBranch                          6
# Employment                          9
# Country                           181
# US_State                           55
# UK_Country                          4
# EdLevel                             9
# Age1stCode                          9
# LearnCode                         458
# YearsCode                          52
# YearsCodePro                       52
# DevType                          8626
# OrgSize                            10
# Currency                          146
# CompTotal                        3752
# CompFreq                            3
# LanguageHaveWorkedWith          28690
# LanguageWantToWorkWith          27545
# DatabaseHaveWorkedWith           3072
# DatabaseWantToWorkWith           3137
# PlatformHaveWorkedWith            118
# PlatformWantToWorkWith            126
# WebframeHaveWorkedWith           5402
# WebframeWantToWorkWith           5113
# ...

# %%
print(f"Unique developper types: {dfU2021.DevType.unique()} ")
devtype = pd.DataFrame(dfU2021.DevType.unique())
devtype
# Out:
# Unique developper types: ['Developer, mobile' nan 'Developer, front-end' ...
#  'Developer, mobile;Developer, front-end;Developer, full-stack;Developer, back-end;Database administrator;Developer, embedded applications or devices;System administrator;Educator'
#  'Developer, front-end;Developer, desktop or enterprise applications;Developer, full-stack;Developer, back-end;Developer, QA or test;Developer, embedded applications or devices;Engineering manager;Educator'
#  'Developer, mobile;Developer, desktop or enterprise applications;Data scientist or machine learning specialist;Developer, back-end;Engineering manager']
#                                                       0
# 0                                     Developer, mobile
# 1                                                   NaN
# 2                                  Developer, front-end
# 3     Developer, desktop or enterprise applications;...
# 4         Data scientist or machine learning specialist
# ...

# %%
dfU2021['LanguageHaveWorkedWith'].describe()
# Out:
# count      82357
# unique     28690
# top       Python
# freq        1337
# Name: LanguageHaveWorkedWith, dtype: object

# %%
dfU2021.describe().round()
# Out:
#        ResponseId     CompTotal  ConvertedCompYearly
# count     83439.0  4.718300e+04              46844.0
# mean      41720.0  2.119407e+69             118426.0
# std       24087.0  4.603702e+71             527294.0
# min           1.0  0.000000e+00                  1.0
# 25%       20860.0  1.600000e+04              27025.0
# 50%       41720.0  6.700000e+04              56211.0
# 75%       62580.0  1.400000e+05             100000.0
# max       83439.0  1.000000e+74           45241312.0

# %% [markdown]
# ## **Task2:**
# #### Cleaned data

# %%
dfP = p3.load_and_process('../data/raw/survey_results_public_2021.csv')
#dfP.to_csv('dfP.csv') dashboard data
print(f"New data frame after cleaning data: {dfP.columns}")
# Out:
# New data frame after cleaning data: Index(['ResponseId', 'MainBranch', 'Employment', 'EdLevel', 'DevType',
#        'LanguageHaveWorkedWith', 'DatabaseHaveWorkedWith',
#        'PlatformHaveWorkedWith', 'WebframeHaveWorkedWith',
#        'MiscTechHaveWorkedWith', 'ToolsTechHaveWorkedWith',
#        'NEWCollabToolsHaveWorkedWith', 'ConvertedCompYearly'],
#       dtype='object')

# %%
count = Counter()
count2 = 0
for i, row in dfP.iterrows():
    rows = str(row['LanguageHaveWorkedWith'])
    listr = rows.split(";")
    for prog in listr:
            count[prog] += 1
countItems = count.items()
itemsList = list(countItems)
dfLang = pd.DataFrame(itemsList)
dfLang.columns = ['Programming Languages', 'Number of Users']
dfLang['Percentage %'] = round((dfLang['Number of Users'] / dfLang['Number of Users'].sum()) * 100,2)

dfLang.loc[lambda row: row['Programming Languages']!="nan"].reset_index().drop(['index'], axis =1) #removes people who wrote in nan
# Out:
#    Programming Languages  Number of Users  Percentage %
# 0                    C++            20057          4.52
# 1               HTML/CSS            46259         10.43
# 2             JavaScript            53587         12.08
# 3            Objective-C             2310          0.52
# 4                    PHP            18130          4.09
# 5                  Swift             4204          0.95
# 6                 Python            39792          8.97
# 7               Assembly             4632          1.04
# 8                      C            17329          3.91
# 9                      R             4185          0.94
# 10                  Rust             5799          1.31
# 11            TypeScript            24909          5.61
# 12            Bash/Shell            22385          5.05
# 13                   SQL            38835          8.75
# 14                    C#            22984          5.18
# 15                  Java            29162          6.57
# ...

# %%
devtype.columns = ['Unique Jobs']
count3 = Counter()
for i, row, in devtype.iterrows():
    rows = str(row['Unique Jobs'])
    listr = rows.split(';')
    for job in listr:
            count3[job] += 1
        
count3Items = count3.items()
itemsList2 = list(count3Items)
UniqueJobs = pd.DataFrame(itemsList2)
UniqueJobs.columns = ['JobTitle', 'Number of People']
UniqueJobs.loc[lambda row: row['JobTitle']!="nan"].reset_index().drop(['index'], axis =1) #removes people who wrote in nan
# Out:
#                                          JobTitle  Number of People
# 0                               Developer, mobile              2610
# 1                            Developer, front-end              3832
# 2   Developer, desktop or enterprise applications              3198
# 3                           Developer, full-stack              5278
# 4                                  Engineer, data              1879
# 5                         Other (please specify):               735
# 6   Data scientist or machine learning specialist              1500
# 7                             Developer, back-end              5351
# 8                             Academic researcher              1137
# 9                          Database administrator              2910
# 10                                      Scientist               937
# 11                                        Student              1178
# 12                          Developer, QA or test              1806
# ...

# %% [markdown]
# - Most Unique Jobs seem to be jobs that have to do with research or higher level
#     developers as well as Marketing jobs.
# - Marketing jobs that require some type of programming are not as popular which is why it's considered a unique job.
# - Most popular jobs are jobs related to web developers, data scientists and mobile developers.

# %%
lang = pd.DataFrame(dfP['LanguageHaveWorkedWith'])
job = pd.DataFrame(dfP['DevType'])
niche = pd.concat([lang, job], axis=1)
counts = niche.groupby(['DevType', 'LanguageHaveWorkedWith']).count()
counts
# Out:
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# ### Seems that theres no specific programming language used for certain jobs. Every job uses a variety of programming languages ###

# %% [markdown]
# **The Above shows all the different languages used at different jobs**

# %% [markdown]
# ## **Visual representation of most and least used languages**

# %%
top10 = dfLang.nlargest(10, 'Number of Users')
bottom10 = dfLang.nsmallest(11, 'Number of Users').loc[lambda row: row['Programming Languages']!="nan"].reset_index().drop(['index'], axis =1) #removes people who wrote in nan

# %%
top10.sort_values(by= ['Number of Users']).reset_index().drop(['index'], axis =1)
# Out:
#   Programming Languages  Number of Users  Percentage %
# 0                   C++            20057          4.52
# 1            Bash/Shell            22385          5.05
# 2                    C#            22984          5.18
# 3            TypeScript            24909          5.61
# 4               Node.js            27975          6.31
# 5                  Java            29162          6.57
# 6                   SQL            38835          8.75
# 7                Python            39792          8.97
# 8              HTML/CSS            46259         10.43
# 9            JavaScript            53587         12.08

# %%
bottom10
# Out:
#   Programming Languages  Number of Users  Percentage %
# 0                 COBOL              437          0.10
# 1               Crystal              466          0.11
# 2                   APL              536          0.12
# 3                Erlang              651          0.15
# 4                    F#              804          0.18
# 5                 Julia             1068          0.24
# 6                  LISP             1096          0.25
# 7                Elixir             1438          0.32
# 8               Clojure             1552          0.35
# 9                Delphi             1731          0.39

# %%
plt.figure(figsize = (16, 16))
sns.set(font_scale = 1.5)
plt.title("Top 10 Most Used Programming Languages of 2021")
sns.barplot(x='Programming Languages', y='Number of Users', data= top10)
#plt.legend(top10['Number of Users'], ncol = 2, loc='upper right')
# Out:
# <AxesSubplot:title={'center':'Top 10 Most Used Programming Languages of 2021'}, xlabel='Programming Languages', ylabel='Number of Users'>

# %% [markdown]
# - JavaScript, HTML and CSS are the most used languages of 2021 because the most popular jobs are front-end developers and full-stack developers. Which are jobs that use those three languages all the time
# - Python and SQL are second highest and are related to more data science jobs, marketing jobs, system administrators and back-end developer jobs.
# - Java is the 5th most popular language because it plays a big part in mobile development jobs. Which is a common job of the survey.

# %%
plt.figure(figsize = (16, 16))
sns.set(font_scale = 1.5)
plt.title("Top 10 Least Used Programming Languages of 2021")
sns.barplot(x='Programming Languages', y='Number of Users', data= bottom10)
#plt.legend(bottom10['Number of Users'], ncol = 2, loc='upper left')
# Out:
# <AxesSubplot:title={'center':'Top 10 Least Used Programming Languages of 2021'}, xlabel='Programming Languages', ylabel='Number of Users'>

# %% [markdown]
# - COBOL is the least used languages of 2021 and it also relates to some of the most unique jobs, such as:
#      - Academic jobs and Marketing jobs
# - Crystal is second least used language and is used in more unique jobs, such as: researchers and scientists

# %% [markdown]
# # **Final Analysis**
#
# I had two questions going into this analysis. The first one being "What programming languages are used the most?". And the second one being "What programming languages are needed to get into more niche careers?/what programming languages are used in niche careers?"(based off # of users).
#
# - During this analysis I found out that the most used programming languages(based off # of users) of 2021 are: Javascript, HTML, CSS, Python, SQL. These top programming languages also match up with the languages used in the top 5 careers of 2021.
#
# - The least used programming languages(based off # of users) of 2021 are: COBOL, Crystal, APL, Erlang F#. These least used languages do not go with the most unpopular careers or 2021.
#
# To answer the second question I have found that there aren't any languages that are only used in specific jobs. Aswell, that the niche jobs don't require a certain programming language in order to do those jobs. Every job seems to use a variety of programming languages and it just depends on what the company is using at the time or whatever programming language your employer requires you to use.
